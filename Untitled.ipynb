# %%
import pandas as pd
import numpy as np

# %%
csv_path = '/home/donjuan/Luna16/csvfiles/annotations.csv'

# %%
df = pd.read_csv(csv_path)
df
# Out:
#                                               seriesuid      coordX  \
# 0     1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222... -128.699421
# 1     1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  103.783651
# 2     1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793...   69.639017
# 3     1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...  -24.013824
# 4     1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...    2.441547
# 5     1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...   90.931713
# 6     1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...   89.540769
# 7     1.3.6.1.4.1.14519.5.2.1.6279.6001.100953483028...   81.509646
# 8     1.3.6.1.4.1.14519.5.2.1.6279.6001.102681962408...  105.055792
# 9     1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760... -124.834262
# 10    1.3.6.1.4.1.14519.5.2.1.6279.6001.105495028985... -106.901301
# 11    1.3.6.1.4.1.14519.5.2.1.6279.6001.106164978370...    2.263816
# 12    1.3.6.1.4.1.14519.5.2.1.6279.6001.106379658920...  -70.550889
# ...

# %%
def select_set(trans_label_df):
    '''
    train_list = trans_label_df['seriesuid'].tolist()
    test_list = sample(train_list, np.int(len(train_list)/10))
    for i in range(len(test_list)):
        train_list.remove(test_list[i])

    return train_list, test_list
    '''
    trans_label_df['dataset'] = np.zeros(trans_label_df.shape[0])
    file_list = trans_label_df['seriesuid'].drop_duplicates().tolist()
    test_list = sample(file_list, np.int(len(file_list)/8))
    trans_label_df.loc[df['seriesuid'].isin(test_list), 'dataset'] = 1

    return trans_label_df, file_list, test_list

# %%
df2 = select_set(df)
df2
# Out:
#                                               seriesuid      coordX  \
# 0     1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222... -128.699421
# 1     1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  103.783651
# 2     1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793...   69.639017
# 3     1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...  -24.013824
# 4     1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...    2.441547
# 5     1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...   90.931713
# 6     1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...   89.540769
# 7     1.3.6.1.4.1.14519.5.2.1.6279.6001.100953483028...   81.509646
# 8     1.3.6.1.4.1.14519.5.2.1.6279.6001.102681962408...  105.055792
# 9     1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760... -124.834262
# 10    1.3.6.1.4.1.14519.5.2.1.6279.6001.105495028985... -106.901301
# 11    1.3.6.1.4.1.14519.5.2.1.6279.6001.106164978370...    2.263816
# 12    1.3.6.1.4.1.14519.5.2.1.6279.6001.106379658920...  -70.550889
# ...

# %%
df2[df2['dataset']==1]
# Out:
#                                               seriesuid      coordX  \
# 8     1.3.6.1.4.1.14519.5.2.1.6279.6001.102681962408...  105.055792
# 9     1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760... -124.834262
# 28    1.3.6.1.4.1.14519.5.2.1.6279.6001.111172165674...  136.434059
# 44    1.3.6.1.4.1.14519.5.2.1.6279.6001.113679818447...   97.370659
# 45    1.3.6.1.4.1.14519.5.2.1.6279.6001.113679818447...   91.009738
# 46    1.3.6.1.4.1.14519.5.2.1.6279.6001.113679818447...  -52.446005
# 76    1.3.6.1.4.1.14519.5.2.1.6279.6001.122621219961...  -58.386356
# 86    1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048...  145.967465
# 98    1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931...   59.114146
# 99    1.3.6.1.4.1.14519.5.2.1.6279.6001.126631670596...   44.016476
# 100   1.3.6.1.4.1.14519.5.2.1.6279.6001.126631670596...  -96.960220
# 106   1.3.6.1.4.1.14519.5.2.1.6279.6001.128881800399...  -99.858522
# 107   1.3.6.1.4.1.14519.5.2.1.6279.6001.128881800399...  -78.667136
# ...

# %%
len(l1)
# Out:
# 601

# %%
from random import sample

# %%
test = sample(l1, np.int(len(l1)/8))
len(test)
# Out:
# 75

# %%
len(l1)
# Out:
# 601

# %%
for i in range(len(test)):
    l1.remove(test[i])

len(l1)
# Out:
# 526

# %%
df['dataset'] = np.zeros(df.shape[0])

# %%
df
# Out:
#                                               seriesuid      coordX  \
# 0     1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222... -128.699421
# 1     1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  103.783651
# 2     1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793...   69.639017
# 3     1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...  -24.013824
# 4     1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...    2.441547
# 5     1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...   90.931713
# 6     1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...   89.540769
# 7     1.3.6.1.4.1.14519.5.2.1.6279.6001.100953483028...   81.509646
# 8     1.3.6.1.4.1.14519.5.2.1.6279.6001.102681962408...  105.055792
# 9     1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760... -124.834262
# 10    1.3.6.1.4.1.14519.5.2.1.6279.6001.105495028985... -106.901301
# 11    1.3.6.1.4.1.14519.5.2.1.6279.6001.106164978370...    2.263816
# 12    1.3.6.1.4.1.14519.5.2.1.6279.6001.106379658920...  -70.550889
# ...

# %%
df['seriesuid'].isin(test)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1156    False
# 1157    False
# 1158    False
# 1159    False
# 1160    False
# 1161    False
# 1162    False
# 1163    False
# 1164    False
# 1165    False
# 1166    False
# 1167    False
# 1168    False
# 1169    False
# 1170    False
# 1171    False
# 1172    False
# 1173    False
# 1174    False
# 1175    False
# 1176    False
# 1177    False
# 1178    False
# 1179    False
# 1180     True
# 1181    False
# 1182    False
# 1183    False
# 1184    False
# 1185    False
# ...

# %%
df.loc[df['seriesuid'].isin(test),'dataset'] = 1

# %%
df
# Out:
#                                               seriesuid      coordX  \
# 0     1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222... -128.699421
# 1     1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  103.783651
# 2     1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793...   69.639017
# 3     1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...  -24.013824
# 4     1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...    2.441547
# 5     1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...   90.931713
# 6     1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...   89.540769
# 7     1.3.6.1.4.1.14519.5.2.1.6279.6001.100953483028...   81.509646
# 8     1.3.6.1.4.1.14519.5.2.1.6279.6001.102681962408...  105.055792
# 9     1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760... -124.834262
# 10    1.3.6.1.4.1.14519.5.2.1.6279.6001.105495028985... -106.901301
# 11    1.3.6.1.4.1.14519.5.2.1.6279.6001.106164978370...    2.263816
# 12    1.3.6.1.4.1.14519.5.2.1.6279.6001.106379658920...  -70.550889
# ...

# %%
import os

# %%
data_path = '/home/donjuan/Luna16/data_set/'
filename = '1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860'

# %%
filename = data_path + filename + '.mhd'

# %%
filename
# Out:
# '/home/donjuan/Luna16/data_set/1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860.mhd'

# %%
filename = data_path + df.ix[0, 'seriesuid'] + '.mhd'

# %%
filename
# Out:
# '/home/donjuan/Luna16/data_set/1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860.mhd'

# %%
filename = '1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860'
df.loc[df['seriesuid']==filename]
# Out:
#                                            seriesuid      coordX      coordY  \
# 0  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222... -128.699421 -175.319272
# 1  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  103.783651 -211.925149
#
#        coordZ  diameter_mm  dataset
# 0 -298.387506     5.651471      0.0
# 1 -227.121250     4.224708      0.0

# %%
df2, file_list, test_list = select_set(df)

# %%
filename = '1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405'

# %%
df3 = df2[df2['seriesuid']==filename]
df3
# Out:
#                                            seriesuid     coordX      coordY  \
# 3  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016... -24.013824  192.102405
# 4  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...   2.441547  172.464881
# 5  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...  90.931713  149.027266
# 6  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...  89.540769  196.405159
#
#        coordZ  diameter_mm  dataset
# 3 -391.081276     8.143262      0.0
# 4 -405.493732    18.545150      0.0
# 5 -426.544715    18.208570      0.0
# 6 -515.073322    16.381276      0.0

# %%
for i in df3.index:
    print df3.loc[i, "coordX"]
# Out:
# -24.0138242
# 2.441546798
# 90.93171321
# 89.54076865
